# %% [markdown]
# # Polynomial fitting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data/tides.csv', header=1)
data.tide += np.random.normal(0, 0.4, len(data))
data.set_index('time', inplace=True)
data.plot();

# %% [markdown]
# Concepts:
# * MSE
# * Bias - variance
# * over-underfitting
# * regularization
# * generalization
